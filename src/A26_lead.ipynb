# %%
import pandas as pd
import numpy as np
import os

# %%
files = [
    "UCLA1-1130444-all-leads.csv",
    "UCLA2-4442242-all-leads.csv",
    "UCLA3-5728091-all-leads.csv"
]

# Load and print first 10 lines of each file
for file in files:
    print(f"\n--- First 10 lines of {file} ---\n")
    try:
        df = pd.read_csv(file)
        print(df.head(10))  # Show first 10 rows
    except Exception as e:
        print(f"Failed to read {file}: {e}")
# Out:
# --- First 10 lines of UCLA1-1130444-all-leads.csv ---
#
#                          Email Email Status Lead First Name Lead Last Name  \
# 0                          NaN          NaN           Nirav          Patel
# 1  jeroen.vantilburg@ionity.eu    CATCH_ALL          Jeroen    Van Tilburg
# 2                          NaN          NaN           Brian         Lillie
# 3                          NaN          NaN            Lara          Rabiu
# 4                          NaN          NaN         Liliana      C  Rieger
# 5              krhee@nachc.org        VALID             Kyu           Rhee
# 6                          NaN          NaN         Allison          Stone
# 7                          NaN          NaN  José Alexander         Herran
# 8                          NaN          NaN            Noel    Castellanos
# 9                          NaN          NaN           Ruchi         Bondre
#
#           Lead Full Name                            Lead Job Title  \
# 0            Nirav Patel                           Founder and CEO
# 1     Jeroen Van Tilburg                   Chief Executive Officer
# 2           Brian Lillie                             President/CEO
# 3             Lara Rabiu  Rockefeller Foundation Bellagio Resident
# 4      Liliana C  Rieger                                   Founder
# 5               Kyu Rhee     President and Chief Executive Officer
# 6          Allison Stone                                Co-Founder
# 7  José Alexander Herran                                      CEO
# 8       Noel Castellanos           Valuation Associate | Centurisk
# 9           Ruchi Bondre                Team Captain - FTC Team 25
#
#                                    Lead Linkedin Url  \
# 0            https://www.linkedin.com/in/niravpatel4
# 1       https://www.linkedin.com/in/jeroentilburgvan
# 2   https://www.linkedin.com/in/brian-lillie-7065a23
# 3     https://www.linkedin.com/in/lara-rabiu-545a8a8
# 4  https://www.linkedin.com/in/liliana-c-rieger-7...
# 5              https://www.linkedin.com/in/kyurheemd
# 6             https://www.linkedin.com/in/allisonbly
# 7             https://www.linkedin.com/in/alexherran
# 8        https://www.linkedin.com/in/castellanosnoel
# 9  https://www.linkedin.com/in/ACwAAEmb3EUBP6svCV...
#
#                                        Company Name  \
# 0                                   Stealth Startup
# 1                                            Ionity
# 2                               The-Party-Staff-Inc
# 3                        The Rockefeller Foundation
# 4                           Liliana Rieger Coaching
# 5  National Association Of Community Health Centers
# 6                                       Williamrose
# 7                                    Formessis-S-A-
# 8                        Constellation-Software-Inc
# 9                                             First
#
#               Company Domain                       Company Website  ...  \
# 0                        NaN                                   NaN  ...
# 1                  ionity.eu                      http://ionity.eu  ...
# 2             partystaff.com                                   NaN  ...
# 3  rockefellerfoundation.org  http://www.rockefellerfoundation.org  ...
# 4                        NaN                                   NaN  ...
# 5                  nachc.org                  http://www.nachc.org  ...
# 6             williamrose.co                                   NaN  ...
# 7                        NaN                     www.formessis.com  ...
# 8            csisoftware.com                                   NaN  ...
# 9          firstinspires.org          http://www.firstinspires.org  ...
#
#   Lead Years In Company Lead Months In Company Lead Position Started Month  \
# 0                     4                    6.0                         9.0
# 1                     0                   10.0                         5.0
# 2                    35                    7.0                         8.0
# 3                     1                    4.0                        11.0
# 4                     5                   11.0                         4.0
# 5                     2                    2.0                         NaN
# 6                     0                    5.0                        10.0
# 7                    13                    9.0                         6.0
# 8                     1                    1.0                         2.0
# 9                     6                    8.0                         5.0
#
#    Lead Position Started Year  \
# 0                      2020.0
# 1                      2024.0
# 2                      1989.0
# 3                      2023.0
# 4                      2019.0
# 5                      2023.0
# 6                      2024.0
# 7                      2011.0
# 8                      2024.0
# 9                      2022.0
#
#                                  Lead Li Picture Url  \
# 0                                                NaN
# 1  https://media.licdn.com/dms/image/v2/D4E03AQHp...
# 2  https://media.licdn.com/dms/image/v2/D5603AQHZ...
# 3  https://media.licdn.com/dms/image/v2/D4E03AQFS...
# 4  https://media.licdn.com/dms/image/v2/C5603AQHR...
# 5  https://media.licdn.com/dms/image/v2/C5603AQGS...
# 6  https://media.licdn.com/dms/image/v2/C4D03AQFz...
# 7  https://media.licdn.com/dms/image/v2/D4E03AQFt...
# 8  https://media.licdn.com/dms/image/v2/C5603AQEj...
# 9  https://media.licdn.com/dms/image/v2/D4D03AQFY...
#
#   Company Location Country Name Company Location Country Code  \
# 0                           NaN                           NaN
# 1                       Germany                            DE
# 2                           NaN                 United States
# 3                 United States                            US
# 4                           NaN                           NaN
# 5                 United States                            US
# 6                           NaN                           NaN
# 7                      Colombia                            CO
# 8                           NaN                        Canada
# 9                 United States                            US
#
#    Company Location City Company Location Timezone  \
# 0                    NaN                       NaN
# 1                 Munich             Europe/Berlin
# 2              Hollywood                       NaN
# 3               New York          America/New_York
# 4                    NaN                       NaN
# 5               Bethesda          America/New_York
# 6                    NaN                       NaN
# 7                  Cali                        NaN
# 8                Toronto                       NaN
# 9             Manchester          America/New_York
#
#   Company Location Timezone Offset
# 0                              NaN
# 1                              2.0
# 2                              NaN
# 3                             -4.0
# 4                              NaN
# 5                             -4.0
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                             -5.0
#
# [10 rows x 38 columns]
#
# --- First 10 lines of UCLA2-4442242-all-leads.csv ---
#
#                               Email Email Status Lead First Name  \
# 0            chill@nexamortgage.com    CATCH_ALL         Camille
# 1                               NaN          NaN         Mersiha
# 2       pschmidt@fffenterprises.com        VALID       Patrick M
# 3                               NaN          NaN             Liz
# 4                   gdotan@ucla.edu        VALID             Guy
# 5              tim.dolan@hawaii.edu    CATCH_ALL             Tim
# 6             brian@warmstealth.xyz    CATCH_ALL           Brian
# 7  jeff.solomon@teachforamerica.org    CATCH_ALL            Jeff
# 8                               NaN          NaN          Walter
# 9                               NaN          NaN             Ben
#
#     Lead Last Name           Lead Full Name  \
# 0             Hill             Camille Hill
# 1  Causevic Podzic  Mersiha Causevic Podzic
# 2          Schmidt       Patrick M  Schmidt
# 3           Lyster               Liz Lyster
# 4            Dotan                Guy Dotan
# 5            Dolan                Tim Dolan
# 6                C                  Brian C
# 7          Solomon             Jeff Solomon
# 8         Williams          Walter Williams
# 9           Eachus               Ben Eachus
#
#                                       Lead Job Title  \
# 0                           Mortgage Loan Originator
# 1                          Communications Specialist
# 2                                                CEO
# 3                                       Health Coach
# 4                                           Lecturer
# 5  CEO, University of Hawai’i Foundation, Vice Pr...
# 6                                            Founder
# 7                              Advisory Board Member
# 8                            Chief Executive Officer
# 9                                             Member
#
#                                    Lead Linkedin Url  \
# 0         https://www.linkedin.com/in/camillehill111
# 1                 https://www.linkedin.com/in/mericp
# 2  https://www.linkedin.com/in/patrick-m-schmidt-...
# 3                https://www.linkedin.com/in/drlizmd
# 4              https://www.linkedin.com/in/guy-dotan
# 5     https://www.linkedin.com/in/tim-dolan-88449021
# 6          https://www.linkedin.com/in/brian-chin-sf
# 7    https://www.linkedin.com/in/jeff-solomon-36041a
# 8         https://www.linkedin.com/in/walterwilliams
# 9              https://www.linkedin.com/in/beneachus
#
#                          Company Name          Company Domain  \
# 0                       Nexa-Mortgage        nexamortgage.com
# 1                               Unodc               unodc.org
# 2                     Fff-Enterprises      fffenterprises.com
# 3                             Optavia                     NaN
# 4  Ucla Anderson School Of Management                ucla.edu
# 5       University Of Hawaii At Manoa              hawaii.edu
# 6                             Stealth         warmstealth.xyz
# 7                   Teach For America     teachforamerica.org
# 8                20Th Century Studios  20thcenturystudios.com
# 9                                 Ypo                 ypo.org
#
#                    Company Website  ... Lead Years In Company  \
# 0                              NaN  ...                     3
# 1                              NaN  ...                     1
# 2                              NaN  ...                    36
# 3                              NaN  ...                    17
# 4         http://anderson.ucla.edu  ...                     1
# 5          http://manoa.hawaii.edu  ...                     6
# 6       http://www.warmstealth.xyz  ...                     3
# 7   http://www.teachforamerica.org  ...                     3
# 8  https://jobs.disneycareers.com/  ...                    25
# 9               http://www.ypo.org  ...                     3
#
#   Lead Months In Company Lead Position Started Month  \
# 0                    6.0                         9.0
# 1                    4.0                        11.0
# 2                    8.0                         7.0
# 3                    2.0                         NaN
# 4                    3.0                        12.0
# 5                    2.0                         1.0
# 6                    2.0                         NaN
# 7                    7.0                         8.0
# 8                    2.0                         1.0
# 9                    2.0                         1.0
#
#    Lead Position Started Year  \
# 0                      2021.0
# 1                      2023.0
# 2                      1988.0
# 3                      2008.0
# 4                      2023.0
# 5                      2019.0
# 6                      2022.0
# 7                      2021.0
# 8                      2000.0
# 9                      2022.0
#
#                                  Lead Li Picture Url  \
# 0  https://media.licdn.com/dms/image/v2/C5603AQEM...
# 1  https://media.licdn.com/dms/image/v2/D4D03AQHb...
# 2  https://media.licdn.com/dms/image/v2/C5103AQGJ...
# 3  https://media.licdn.com/dms/image/v2/D5603AQF4...
# 4  https://media.licdn.com/dms/image/v2/C4E03AQHZ...
# 5  https://media.licdn.com/dms/image/v2/C5603AQFC...
# 6  https://media.licdn.com/dms/image/v2/C5103AQEp...
# 7  https://media.licdn.com/dms/image/v2/C4E03AQFW...
# 8  https://media.licdn.com/dms/image/v2/C5603AQFm...
# 9  https://media.licdn.com/dms/image/v2/C5603AQHt...
#
#   Company Location Country Name Company Location Country Code  \
# 0                           NaN                 United States
# 1                           NaN                           NaN
# 2                           NaN                 United States
# 3                           NaN                           NaN
# 4                 United States                            US
# 5                 United States                            US
# 6                 United States                            US
# 7                 United States                            US
# 8                 United States                            US
# 9                 United States                            US
#
#    Company Location City Company Location Timezone  \
# 0               Chandler                       NaN
# 1                    NaN                       NaN
# 2               Temecula                       NaN
# 3                    NaN                       NaN
# 4            Los Angeles          America/New_York
# 5               Honolulu          America/New_York
# 6            Los Angeles          America/New_York
# 7               New York          America/New_York
# 8               New York          America/New_York
# 9                 Irving          America/New_York
#
#   Company Location Timezone Offset
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                             -4.0
# 5                             -4.0
# 6                             -4.0
# 7                             -5.0
# 8                             -4.0
# 9                             -5.0
#
# [10 rows x 38 columns]
#
# --- First 10 lines of UCLA3-5728091-all-leads.csv ---
#   Email Email Status Lead First Name Lead Last Name     Lead Full Name  \
# 0   NaN          NaN            Seth          Koshy         Seth Koshy
# 1   NaN          NaN            Jack         Nilles               Jack
# 2   NaN          NaN        Jeremy A          Lyons    Jeremy A  Lyons
# 3   NaN          NaN          Steven        Diebold     Steven Diebold
# 4   NaN          NaN            Cali        Gilbert       Cali Gilbert
# 5   NaN          NaN           Suraj      Palaparty    Suraj Palaparty
# 6   NaN          NaN           Yusuf          Yucel        Yusuf Yucel
# 7   NaN          NaN         Rydhima      Shah Brar  Rydhima Shah Brar
# 8   NaN          NaN             Eti        El-Kiss        Eti El-Kiss
# 9   NaN          NaN           Gabby         Stuart       Gabby Stuart
#
#                                   Lead Job Title  \
# 0                   Founder/CEO/District Manager
# 1                                            CEO
# 2  Co-Founder | Recruiting Operations Consultant
# 3                                    Founder-CEO
# 4                                  Founder & CEO
# 5                                   Founder, CEO
# 6                                  Founder & CEO
# 7                            Founder & Principal
# 8                                     CEO/Broker
# 9                                        Founder
#
#                                    Lead Linkedin Url  \
# 0              https://www.linkedin.com/in/sethkoshy
# 1  https://www.linkedin.com/in/jack-john-m-nilles...
# 2            https://www.linkedin.com/in/lyonsjeremy
# 3          https://www.linkedin.com/in/stevendiebold
# 4            https://www.linkedin.com/in/caligilbert
# 5        https://www.linkedin.com/in/suraj-palaparty
# 6             https://www.linkedin.com/in/yusufyucel
# 7            https://www.linkedin.com/in/rydhimabrar
# 8   https://www.linkedin.com/in/eti-el-kiss-85aaa641
# 9  https://www.linkedin.com/in/gabby-stuart-31846b73
#
#                             Company Name                 Company Domain  \
# 0               S Koshy Insurance Agency                            NaN
# 1                     Jala International                            NaN
# 2                      Recops Collective           recopscollective.com
# 3  Papa Steve'S No Junk Raw Protein Bars                            NaN
# 4                   Tower 15 Productions         tower15productions.com
# 5              Caduceus-Technologies-Llc                            NaN
# 6                             Nova Agent                            NaN
# 7                          Rteriorstudio                            NaN
# 8            Conquest Realty Investments  conquestrealtyinvestments.com
# 9                             Revere-Mkt                  reveremkt.com
#
#                          Company Website  ... Lead Years In Company  \
# 0                                    NaN  ...                    17
# 1                                    NaN  ...                    44
# 2               www.recopscollective.com  ...                     2
# 3                                    NaN  ...                    13
# 4    https://www.tower15productions.com/  ...                    10
# 5                                    NaN  ...                     1
# 6                                    NaN  ...                     1
# 7         https://www.rteriorstudio.com/  ...                     5
# 8  https://conquestrealtyinvestments.com  ...                     8
# 9                                    NaN  ...                     0
#
#   Lead Months In Company Lead Position Started Month  \
# 0                   11.0                         4.0
# 1                    5.0                        10.0
# 2                    4.0                        11.0
# 3                    6.0                         9.0
# 4                    3.0                        12.0
# 5                    NaN                         3.0
# 6                    NaN                         3.0
# 7                    NaN                         3.0
# 8                    2.0                         1.0
# 9                    4.0                        11.0
#
#    Lead Position Started Year  \
# 0                      2007.0
# 1                      1980.0
# 2                      2022.0
# 3                      2011.0
# 4                      2014.0
# 5                      2024.0
# 6                      2024.0
# 7                      2020.0
# 8                      2017.0
# 9                      2024.0
#
#                                  Lead Li Picture Url  \
# 0  https://media.licdn.com/dms/image/v2/C5603AQHY...
# 1  https://media.licdn.com/dms/image/v2/C5603AQG9...
# 2  https://media.licdn.com/dms/image/v2/D5603AQHb...
# 3  https://media.licdn.com/dms/image/v2/C4E03AQEJ...
# 4  https://media.licdn.com/dms/image/v2/D5603AQHt...
# 5                                                NaN
# 6  https://media.licdn.com/dms/image/v2/D5603AQHD...
# 7  https://media.licdn.com/dms/image/v2/C5603AQGI...
# 8  https://media.licdn.com/dms/image/v2/D5603AQHY...
# 9  https://media.licdn.com/dms/image/v2/C5603AQF-...
#
#   Company Location Country Name Company Location Country Code  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                 United States                            US
# 3                           NaN                           NaN
# 4                 United States                            US
# 5                           NaN                 United States
# 6                 United States                            US
# 7                 United States                 United States
# 8                           NaN                           NaN
# 9                           NaN                           NaN
#
#    Company Location City Company Location Timezone  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2          San Francisco          America/New_York
# 3                    NaN                       NaN
# 4            Los Angeles          America/New_York
# 5            Los Angeles                       NaN
# 6         Marina Del Rey          America/New_York
# 7            Los Angeles                       NaN
# 8                    NaN                       NaN
# 9                    NaN                       NaN
#
#   Company Location Timezone Offset
# 0                              NaN
# 1                              NaN
# 2                             -5.0
# 3                              NaN
# 4                             -5.0
# 5                              NaN
# 6                             -5.0
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
# [10 rows x 38 columns]

# %%
def read_csv_simple(path):
    return pd.read_csv(path, encoding="utf-8-sig")

# %%
def preprocess_min(df, source_name):
    df = df.copy()
    df["__source_file"] = source_name

    if "Email" in df.columns:
        df["Email"] = (df["Email"].astype(str)
                       .str.strip().str.lower()
                       .replace({"": pd.NA, "nan": pd.NA}))
    if "Email Status" in df.columns:
        df["Email Status"] = (df["Email Status"].astype(str)
                              .str.strip().str.upper()
                              .replace({"": pd.NA, "NAN": pd.NA}))
    if "Company Domain" in df.columns:
        df["Company Domain"] = (df["Company Domain"].astype(str)
                                .str.strip().str.lower()
                                .replace({"": pd.NA, "nan": pd.NA}))
    if "Lead Linkedin Url" in df.columns:
        df["Lead Linkedin Url"] = (df["Lead Linkedin Url"].astype(str)
                                   .str.strip()
                                   .replace({"": pd.NA, "nan": pd.NA}))
    return df

# %%
# 1) Read + minimal normalization
dfs = [preprocess_min(read_csv_simple(p), os.path.basename(p)) for p in files]

# 2) Schema union
all_cols = sorted(set().union(*[set(d.columns) for d in dfs]))
aligned = []
for df in dfs:
    for c in all_cols:
        if c not in df.columns:
            df[c] = pd.NA
    aligned.append(df[all_cols])

stacked = pd.concat(aligned, ignore_index=True)

# %%
# 3) De-duplicate
has_email = stacked["Email"].notna() if "Email" in stacked.columns else pd.Series(False, index=stacked.index)
df_with_email = stacked[has_email].copy()
df_no_email  = stacked[~has_email].copy()

status_score = {"VALID": 2, "CATCH_ALL": 1}
df_with_email["__status_score"] = df_with_email.get("Email Status").map(status_score).fillna(0).astype(int)

# completeness on user columns only (exclude helper cols)
helper_cols = {"__status_score"}
value_cols = [c for c in df_with_email.columns if c not in helper_cols]
df_with_email["__completeness"] = df_with_email[value_cols].notna().sum(axis=1)

source_order = {os.path.basename(p): i for i, p in enumerate(files)}
df_with_email["__source_priority"] = df_with_email["__source_file"].map(source_order).fillna(len(files)).astype(int)

# sort preference
df_with_email = df_with_email.sort_values(
    by=["__status_score", "__completeness", "__source_priority"],
    ascending=[False, False, True]
)

# Group-wise consolidation + change tracking
def consolidate_group(g):
    # g already sorted with best row first
    best = g.iloc[0].copy()
    base_before = best.copy()  # snapshot to detect changes after consolidation
    for col in g.columns:
        if col.startswith("__"):
            continue
        if pd.isna(best[col]):
            for v in g[col].iloc[1:]:
                if pd.notna(v):
                    best[col] = v
                    break
    # Which columns changed due to consolidation?
    changed_cols = []
    for col in g.columns:
        if col.startswith("__"):
            continue
        old = base_before[col]
        new = best[col]
        # consider NaN equality
        if (pd.isna(old) and pd.notna(new)) or (pd.notna(old) and pd.isna(new)) or (pd.notna(old) and pd.notna(new) and old != new):
            changed_cols.append(col)
    # Prepare a small record for change_log
    kept = best.copy()
    kept["__changed_columns"] = ", ".join(changed_cols) if changed_cols else ""
    kept["__n_rows_in_group"] = len(g)
    kept["__group_sources"] = ", ".join(g["__source_file"].astype(str).unique().tolist())
    kept["__group_statuses"] = ", ".join(g["Email Status"].astype(str).fillna("NA").unique().tolist())
    return kept

consolidated = df_with_email.copy()

# For rows without Email: drop exact duplicates
no_email_clean = df_no_email.drop_duplicates()

merged = pd.concat([consolidated, no_email_clean], ignore_index=True)

# %%
# 4) Build change logs / summary
n_before = len(stacked)
n_after  = len(merged)

# Count emails that appear >1 time in the final data (kept, not collapsed)
if "Email" in merged.columns:
    email_counts_final = merged["Email"].value_counts(dropna=True)
    emails_repeated_final = email_counts_final[email_counts_final > 1]
    n_emails_repeated_final = int((emails_repeated_final > 1).sum())
else:
    n_emails_repeated_final = 0

print("=== Summary ===")
print(f"Rows before: {n_before}")
print(f"Rows after:  {n_after}")
print(f"Emails that appear >1 time (kept): {n_emails_repeated_final}")
# Out:
# === Summary ===
# Rows before: 4358
# Rows after:  4358
# Emails that appear >1 time (kept): 1

# %%
# Summary table
summary_rows = [{
    "files_merged": ", ".join(os.path.basename(p) for p in files),
    "rows_before": n_before,
    "rows_after": n_after,
    "duplicates_removed_total": n_before - n_after,
    "email_groups_with_duplicates": n_email_groups_gt1,
    "rows_without_email_before": n_no_email_before,
    "rows_without_email_after": n_no_email_after,
    "no_email_exact_dups_removed": n_no_email_dups_removed,
}]
summary_df = pd.DataFrame(summary_rows)

# %%
print(summary_df)
# Out:
#                                         files_merged  rows_before  rows_after  \
# 0  UCLA1-1130444-all-leads.csv, UCLA2-4442242-all...         4358        4358
#
#    duplicates_removed_total  email_groups_with_duplicates  \
# 0                         0                             1
#
#    rows_without_email_before  rows_without_email_after  \
# 0                       3206                      3206
#
#    no_email_exact_dups_removed
# 0                            0

# %%
if "Email" in merged.columns:
    dup_counts = merged["Email"].value_counts(dropna=True)
    dup_emails = dup_counts[dup_counts > 1]
    print("Duplicate emails kept:\n", dup_emails.to_string())

    # Show the actual rows for those emails
    dup_rows = merged[merged["Email"].isin(dup_emails.index)].sort_values(["Email"])
    print("\nFirst few duplicate rows:\n", dup_rows.head(20))
# Out:
# Duplicate emails kept:
#  Email
# eric@eonetwork.org    2
#
# First few duplicate rows:
#       Company Domain  Company Followers  Company Founded In  \
# 588   eonetwork.org           127728.0              1987.0
# 1065  eonetwork.org              637.0                 NaN
#
#                         Company Industry Company Li Company Type  \
# 588             Non-profit Organizations               Nonprofit
# 1065  Professional Training and Coaching              Non Profit
#
#                                  Company Li Description  \
# 588   The Entrepreneurs’ Organization (EO) is a high...
# 1065  At EO Accelerator, being one of EO's primary g...
#
#                                        Company Linkedin Company Location City  \
# 588   https://www.linkedin.com/company/entrepreneursorg            Alexandria
# 1065  https://www.linkedin.com/company/eo-accelerato...                Dubai
#
#      Company Location Country Code Company Location Country Name  ...  \
# 588                             US                 United States  ...
# 1065          United Arab Emirates                           NaN  ...
#
#      Lead Position Started Month  Lead Position Started Year Lead Premium  \
# 588                          9.0                      2016.0          yes
# 1065                         8.0                      2024.0           no
#
#                                            Lead Summary Lead Years In Company  \
# 588   Eric has generated well into the 8 figures in ...                     8
# 1065  I’m an entrepreneur with over 14 years of expe...                     0
#
#      Lead Years In Position                __source_file __status_score  \
# 588                       8  UCLA2-4442242-all-leads.csv            1.0
# 1065                      0  UCLA2-4442242-all-leads.csv            1.0
#
#       __completeness __source_priority
# 588             39.0               1.0
# 1065            32.0               1.0
#
# [2 rows x 42 columns]

# %%
#Descending Order by Company Founded In YEAR
if "Company Founded In" in merged.columns:
    merged = merged.sort_values(by="Company Founded In", ascending=False)

#Download
out_csv = "UCLA-merged-all-leads.csv"
merged.to_csv(out_csv, index=False)

print(f"Merged CSV saved to: {out_csv}  (rows={len(merged)})")
# Out:
# Merged CSV saved to: UCLA-merged-all-leads.csv  (rows=4358)

# %%
dfOut = pd.read_csv("UCLA-merged-all-leads.csv")
print(dfOut.head(10))
# Out:
#                      Company Domain  Company Followers  Company Founded In  \
# 0                               NaN                1.0              2025.0
# 1                               NaN                1.0              2025.0
# 2                    motormeter.org                3.0              2025.0
# 3                  ammapartners.com                9.0              2025.0
# 4                    csuite-law.com                1.0              2025.0
# 5                               NaN                9.0              2025.0
# 6            aspirelegalnetwork.com                1.0              2025.0
# 7                       futuxre.com                1.0              2025.0
# 8  myprivateprofessorfoundation.org               17.0              2025.0
# 9                    blairheard.com                3.0              2025.0
#
#              Company Industry Company Li Company Type  \
# 0  Retail Apparel and Fashion     Sole Proprietorship
# 1                 Real Estate          Privately Held
# 2       Retail Motor Vehicles          Privately Held
# 3          Marketing Services             Partnership
# 4                Law Practice          Privately Held
# 5            Higher Education          Public Company
# 6              Legal Services             Partnership
# 7     Entertainment Providers           Self-Employed
# 8    Non-profit Organizations               Nonprofit
# 9     Staffing and Recruiting             Partnership
#
#                               Company Li Description  \
# 0  We aim to redefine brand-building by empowerin...
# 1  Zeus Development is a full-service real estate...
# 2  We aim to serve as the trusted and comprehensi...
# 3  In a world saturated with choice, Amma helps b...
# 4  Executive compensation and employee benefits l...
# 5  Providing expert online admissions consulting ...
# 6  Aspire brings AM Law 200 resources to boutique...
# 7  FutuXRe was founded on the belief that the Int...
# 8  My Private Professor Foundation is a 501(c)(3)...
# 9  Executive Search Blair Heard’s expertise in re...
#
#                                     Company Linkedin Company Location City  \
# 0     https://www.linkedin.com/company/emrgnt-studio           Los Angeles
# 1  https://www.linkedin.com/company/zeusdevelopment/                   NaN
# 2       https://www.linkedin.com/company/motormeter/           Los Angeles
# 3     https://www.linkedin.com/company/ammapartners/              New York
# 4       https://www.linkedin.com/company/c-suite-law                   NaN
# 5          https://www.linkedin.com/company/counsly/                   NaN
# 6  https://www.linkedin.com/company/aspire-legal-...              Pasadena
# 7           https://www.linkedin.com/company/futuxre          Los Angeles
# 8  https://www.linkedin.com/company/my-private-pr...                   NaN
# 9  https://www.linkedin.com/company/blair-heard-e...                   NaN
#
#   Company Location Country Code Company Location Country Name  ...  \
# 0                            US                 United States  ...
# 1                           NaN                           NaN  ...
# 2                 United States                           NaN  ...
# 3                 United States                           NaN  ...
# 4                           NaN                           NaN  ...
# 5                           NaN                           NaN  ...
# 6                 United States                           NaN  ...
# 7                            US                 United States  ...
# 8                           NaN                           NaN  ...
# 9                           NaN                           NaN  ...
#
#   Lead Position Started Month  Lead Position Started Year Lead Premium  \
# 0                         1.0                      2025.0           no
# 1                         1.0                      2025.0           no
# 2                        12.0                      2024.0           no
# 3                        11.0                      2024.0           no
# 4                         2.0                      2025.0           no
# 5                         1.0                      2025.0           no
# 6                         1.0                      2025.0          yes
# 7                         2.0                      2025.0           no
# 8                         1.0                      2025.0          yes
# 9                         1.0                      2025.0          yes
#
#                                         Lead Summary Lead Years In Company  \
# 0  I don't do "niche" the way others do. Because ...                     0
# 1  Zeus Hernandez is an entrepreneur, investor, a...                     0
# 2                                                NaN                     0
# 3  Cutting through the noise to amplify brands th...                     0
# 4  Stephen Harris is the founder and managing par...                     0
# 5                                                NaN                     0
# 6                                                NaN                     0
# 7  Over a decade plus of experience in Business &...                     0
# 8  Sona Shah is the Founder & CEO of My Private P...                     0
# 9  Camilo is a seasoned executive search professi...                     0
#
#   Lead Years In Position                __source_file __status_score  \
# 0                      0  UCLA3-5728091-all-leads.csv            NaN
# 1                      0  UCLA3-5728091-all-leads.csv            NaN
# 2                      0  UCLA1-1130444-all-leads.csv            NaN
# 3                      0  UCLA3-5728091-all-leads.csv            2.0
# 4                      0  UCLA3-5728091-all-leads.csv            NaN
# 5                      0  UCLA3-5728091-all-leads.csv            NaN
# 6                      0  UCLA3-5728091-all-leads.csv            NaN
# 7                      0  UCLA3-5728091-all-leads.csv            NaN
# 8                      0  UCLA3-5728091-all-leads.csv            NaN
# 9                      0  UCLA2-4442242-all-leads.csv            2.0
#
#    __completeness __source_priority
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3            35.0               2.0
# 4             NaN               NaN
# 5             NaN               NaN
# 6             NaN               NaN
# 7             NaN               NaN
# 8             NaN               NaN
# 9            30.0               1.0
#
# [10 rows x 42 columns]

# %%
# What columns do we have?
print(sorted(merged.columns))

# Look for any plausible name columns (case-insensitive)
print([c for c in merged.columns if "name" in c.lower()])
# Out:
# ['Company Domain', 'Company Followers', 'Company Founded In', 'Company Industry', 'Company Li Company Type', 'Company Li Description', 'Company Linkedin', 'Company Location City', 'Company Location Country Code', 'Company Location Country Name', 'Company Location Timezone', 'Company Location Timezone Offset', 'Company Name', 'Company Size', 'Company Specialities', 'Company Website', 'Email', 'Email Status', 'Lead Connection Degree', 'Lead First Name', 'Lead Full Name', 'Lead Job Title', 'Lead Last Name', 'Lead Li Picture Url', 'Lead Linkedin Url', 'Lead Location City', 'Lead Location Country Name', 'Lead Location Raw', 'Lead Location State', 'Lead Months In Company', 'Lead Months In Position', 'Lead Open Profile', 'Lead Position Started Month', 'Lead Position Started Year', 'Lead Premium', 'Lead Summary', 'Lead Years In Company', 'Lead Years In Position', '__completeness', '__source_file', '__source_priority', '__status_score']
# ['Company Location Country Name', 'Company Name', 'Lead First Name', 'Lead Full Name', 'Lead Last Name', 'Lead Location Country Name']
